# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\Downloads\cancer.csv")
data.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
data=data.drop(columns=['Unnamed: 32'])

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
sns.pairplot(data,hue = 'diagnosis', palette= 'coolwarm', vars = ['radius_mean', 'texture_mean', 'perimeter_mean','area_mean','smoothness_mean'])

# %%
# visualize the count:
sns.countplot(data['diagnosis'], label = 'count')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
# define the dependent variable that need to predict(label)
y = data['diagnosis'].values
print(np.unique(y))
# Out:
# ['B' 'M']

# %%
# Encoding categorical data from text(B and M) to integers (0 and 1)
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y) # M = 1 and B = 0
print(np.unique(y))
# Out:
# [0 1]

# %%
# define x and normalize / scale value:

# define the independent variables, Drop label and ID, and normalize other data:
X  = data.drop(labels=['diagnosis','id'],axis = 1)

#scale / normalize the values to bring them into similar range:
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)

print(X)
# Out:
# [[0.52 0.02 0.55 ... 0.91 0.6  0.42]
#  [0.64 0.27 0.62 ... 0.64 0.23 0.22]
#  [0.6  0.39 0.6  ... 0.84 0.4  0.21]
#  ...
#  [0.46 0.62 0.45 ... 0.49 0.13 0.15]
#  [0.64 0.66 0.67 ... 0.91 0.5  0.45]
#  [0.04 0.5  0.03 ... 0.   0.26 0.1 ]]

# %%
feature_data=data[['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']]
feature=feature_data

# %%
X=np.asarray(feature_data)
y=np.asarray(data['diagnosis'])

# %%
X
# Out:
# array([[1.80e+01, 1.04e+01, 1.23e+02, ..., 2.65e-01, 4.60e-01, 1.19e-01],
#        [2.06e+01, 1.78e+01, 1.33e+02, ..., 1.86e-01, 2.75e-01, 8.90e-02],
#        [1.97e+01, 2.12e+01, 1.30e+02, ..., 2.43e-01, 3.61e-01, 8.76e-02],
#        ...,
#        [1.66e+01, 2.81e+01, 1.08e+02, ..., 1.42e-01, 2.22e-01, 7.82e-02],
#        [2.06e+01, 2.93e+01, 1.40e+02, ..., 2.65e-01, 4.09e-01, 1.24e-01],
#        [7.76e+00, 2.45e+01, 4.79e+01, ..., 0.00e+00, 2.87e-01, 7.04e-02]])

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.25,random_state=0)

# %%
print('Train set:', X_train.shape,  y_train.shape)
print('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (426, 30) (426,)
# Test set: (143, 30) (143,)

# %%
classifier=SVC(kernel="linear")
classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score
y_pred=classifier.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.958041958041958

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
classifier.score(X_test,y_test)
# Out:
# 0.958041958041958

# %%
confusion_matrix(y_test,y_pred)
pd.crosstab(y_test,y_pred,rownames=["Actual"],colnames=["predicted"],margins=True)
# Out:
# predicted   B   M  All
# Actual
# B          85   5   90
# M           1  52   53
# All        86  57  143

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# %%
print (classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.99      0.94      0.97        90
#            M       0.91      0.98      0.95        53
#
#     accuracy                           0.96       143
#    macro avg       0.95      0.96      0.96       143
# weighted avg       0.96      0.96      0.96       143

# %%
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['Benign(2)','Malignant(4)'],normalize= False,  title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[85  5]
#  [ 1 52]]

# %%
kernel=['linear','poly','rbf','sigmoid']
for i in kernel:
    model=SVC(kernel=i,C=1.0)
    model.fit(X_train,y_train)
    print("for Kernal:",i)
    print("Accuracy score:",model.score(X_test,y_test))
# Out:
# for Kernal: linear
# Accuracy score: 0.958041958041958
# for Kernal: poly
# Accuracy score: 0.9230769230769231
# for Kernal: rbf
# Accuracy score: 0.9370629370629371
# for Kernal: sigmoid
# Accuracy score: 0.45454545454545453

# %%
model=SVC() 
model.fit(X_train,y_train) 
print("Accuracy on testing data is:",model.score(X_test,y_test)) 
print("Accuracy on training data is:",model.score(X_train,y_train))
# Out:
# Accuracy on testing data is: 0.9370629370629371
# Accuracy on training data is: 0.903755868544601

# %%
for i in range(1,10):
    model=SVC(kernel='linear',degree=i,C=100)
    model.fit(X_train,y_train)
    print("Accuracy on testing data for degree:", i ,"is",model.score(X_test,y_test)) 
    print("Accuracy on training data for degree:", i ,"is",model.score(X_train,y_train))
# Out:
# Accuracy on testing data for degree: 1 is 0.965034965034965
# Accuracy on training data for degree: 1 is 0.9765258215962441
# Accuracy on testing data for degree: 2 is 0.965034965034965
# Accuracy on training data for degree: 2 is 0.9765258215962441
# Accuracy on testing data for degree: 3 is 0.965034965034965
# Accuracy on training data for degree: 3 is 0.9765258215962441
# Accuracy on testing data for degree: 4 is 0.965034965034965
# Accuracy on training data for degree: 4 is 0.9765258215962441
# Accuracy on testing data for degree: 5 is 0.965034965034965
# Accuracy on training data for degree: 5 is 0.9765258215962441
# Accuracy on testing data for degree: 6 is 0.965034965034965
# Accuracy on training data for degree: 6 is 0.9765258215962441
# Accuracy on testing data for degree: 7 is 0.965034965034965
# Accuracy on training data for degree: 7 is 0.9765258215962441
# Accuracy on testing data for degree: 8 is 0.965034965034965
# ...

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,100,1000],'kernel':['rbf','poly','sigmoid','linear'],'degree':[1,2,3,4,5,6]}
grid=GridSearchCV(SVC(),param_grid)
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'degree': [1, 2, 3, 4, 5, 6],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']})

# %%
print(grid.best_params_)
print(grid.score(X_test,y_test))
# Out:
# {'C': 100, 'degree': 1, 'kernel': 'linear'}
# 0.965034965034965

# %% [markdown]
# from hyper parameter tuning,
# we commclude that linear kernel with degree as 1 and C as 100
# gives us the highest accuracy score
# Training data-97.6%
# Test data-96.5%
# So this is advisible

# %%
# from sklearn import svm, datasets
# x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
# y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
# h = (x_max / x_min)/100
# xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
# X_plot = np.c_[xx.ravel(), yy.ravel()]

# %%
# C = 1.0
# svc_classifier = svm.SVC(kernel='linear', C=C).fit(X, y)

# Z = svc_classifier.predict(X_test)

# %%
# plt.figure(figsize=(15, 5))
# plt.subplot(121)
# plt.contourf(xx, yy, Z,alpha=0.3)
# plt.set_cmap("gist_rainbow") 
# plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
# plt.xlabel('features')
# plt.ylabel('diagnosis')
# plt.xlim(xx.min(), xx.max())
# plt.title('Support Vector Classifier with linear kernel')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [90], in <cell line: 3>()
#       1 plt.figure(figsize=(15, 5))
#       2 plt.subplot(121)
# ----> 3 plt.contour(xx, yy, Z,alpha=0.3)
#       4 plt.set_cmap("gist_rainbow")
#       5 plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2472, in contour(data, *args, **kwargs)
#    2470 @_copy_docstring_and_deprecators(Axes.contour)
#    2471 def contour(*args, data=None, **kwargs):
# -> 2472     __ret = gca().contour(
#    2473         *args, **({"data": data} if data is not None else {}),
#    2474         **kwargs)
#    2475     if __ret._A is not None: sci(__ret)  # noqa
#    2476     return __ret
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
# ...

# %%
# ax = data[data['diagnosis'] ==1][:50].plot(kind='scatter', x='radius_mean', y='diagnosis', color='DarkBlue', label='malignant');
# data[data['diagnosis'] ==0][:50].plot(kind='scatter', x='radius_mean', y='diagnosis', color='Yellow', label='benign', ax=ax);
# plt.show()
